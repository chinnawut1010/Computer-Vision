# %%
from tensorflow import keras
from keras.layers import Conv2D, Dense, Dropout, Flatten
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import MaxPooling2D, GlobalMaxPooling2D
from matplotlib import pyplot as plt
from keras import datasets
from keras.utils.np_utils import to_categorical
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

# %%
# Load CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = keras.datasets.cifar10.load_data()

# %%
# Define the labels of the dataset
labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 
          'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# Let's view more images in a grid format
# Define the dimensions of the plot grid 
W_grid = 10
L_grid = 10

fig, axes = plt.subplots(L_grid, W_grid, figsize=(17,17))
axes = axes.ravel() # Flatten the 10 x 10 matrix into 100 array
n_train = len(train_images) # Get the length of the train dataset

# Select a random number from 0 to n_train
for i in np.arange(0, W_grid * L_grid): # Create evenly spaced variables 
    index = np.random.randint(0, n_train) # Select a random number
    axes[i].imshow(train_images[index]) # Read and display an image with the selected index    
    label_index = int(train_labels[index])
    axes[i].set_title(labels[label_index], fontsize=8)
    axes[i].axis('off')

plt.subplots_adjust(hspace=0.4)
# Out:
# C:\Users\chinnawut\AppData\Local\Temp\ipykernel_20452\3558592864.py:14: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label_index = int(train_labels[index])

# %%
# Normalize the images
train_images, test_images = train_images / 255.0, test_images / 255.0

# %%
# Load pre-trained VGG16 model + higher level layers
from keras.applications.vgg16 import VGG16

IMG_SHAPE = (32, 32, 3)
base_model = VGG16(
    input_shape=IMG_SHAPE,
    include_top=False,
    weights='imagenet'
)

# Freeze the pre-trained model weights
base_model.trainable = True

for layer in base_model.layers[:15]:
    layer.trainable = False

# Trainable classification head
maxpool_layer = GlobalMaxPooling2D()
prediction_layer = Dense(units=10, activation='softmax')
# Layer classification head with feature detector
model = Sequential([
    base_model,
    maxpool_layer,
    prediction_layer
])

# Compile the model
model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=['accuracy'])

# %%
# Print model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 1, 1, 512)         14714688
#
#  global_max_pooling2d (Globa  (None, 512)              0
#  lMaxPooling2D)
#
#  dense (Dense)               (None, 10)                5130
#
# =================================================================
# Total params: 14,719,818
# Trainable params: 7,084,554
# Non-trainable params: 7,635,264
# _________________________________________________________________

# %%
# Train the model
hist = model.fit(train_images, train_labels, epochs=50, validation_data=(test_images, test_labels))
# Out:
# Epoch 1/50
# 1563/1563 [==============================] - 27s 15ms/step - loss: 1.0874 - accuracy: 0.6236 - val_loss: 0.9007 - val_accuracy: 0.6873
# Epoch 2/50
# 1563/1563 [==============================] - 21s 13ms/step - loss: 0.8035 - accuracy: 0.7240 - val_loss: 0.8304 - val_accuracy: 0.7172
# Epoch 3/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.7088 - accuracy: 0.7543 - val_loss: 0.8137 - val_accuracy: 0.7237
# Epoch 4/50
# 1563/1563 [==============================] - 21s 13ms/step - loss: 0.6324 - accuracy: 0.7792 - val_loss: 0.7804 - val_accuracy: 0.7342
# Epoch 5/50
# 1563/1563 [==============================] - 21s 13ms/step - loss: 0.5795 - accuracy: 0.7989 - val_loss: 0.8407 - val_accuracy: 0.7276
# Epoch 6/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.5199 - accuracy: 0.8197 - val_loss: 0.8357 - val_accuracy: 0.7323
# Epoch 7/50
# 1563/1563 [==============================] - 21s 13ms/step - loss: 0.4703 - accuracy: 0.8353 - val_loss: 0.8541 - val_accuracy: 0.7343
# Epoch 8/50
# 1563/1563 [==============================] - 21s 13ms/step - loss: 0.4206 - accuracy: 0.8531 - val_loss: 0.9143 - val_accuracy: 0.7378
# Epoch 9/50
# 1563/1563 [==============================] - 21s 14ms/step - loss: 0.3860 - accuracy: 0.8657 - val_loss: 0.9300 - val_accuracy: 0.7381
# Epoch 10/50
# 1563/1563 [==============================] - 21s 14ms/step - loss: 0.3440 - accuracy: 0.8814 - val_loss: 0.9612 - val_accuracy: 0.7356
# Epoch 11/50
# 1563/1563 [==============================] - 21s 14ms/step - loss: 0.3093 - accuracy: 0.8918 - val_loss: 1.0737 - val_accuracy: 0.7365
# Epoch 12/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.2787 - accuracy: 0.9044 - val_loss: 1.1295 - val_accuracy: 0.7343
# Epoch 13/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.2611 - accuracy: 0.9089 - val_loss: 1.1835 - val_accuracy: 0.7371
# Epoch 14/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.2356 - accuracy: 0.9195 - val_loss: 1.2507 - val_accuracy: 0.7351
# Epoch 15/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.2171 - accuracy: 0.9264 - val_loss: 1.3253 - val_accuracy: 0.7207
# Epoch 16/50
# 1563/1563 [==============================] - 26s 16ms/step - loss: 0.2016 - accuracy: 0.9317 - val_loss: 1.3296 - val_accuracy: 0.7262
# Epoch 17/50
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.1874 - accuracy: 0.9364 - val_loss: 1.4653 - val_accuracy: 0.7341
# Epoch 18/50
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.1733 - accuracy: 0.9418 - val_loss: 1.4450 - val_accuracy: 0.7332
# Epoch 19/50
# 1563/1563 [==============================] - 30s 19ms/step - loss: 0.1737 - accuracy: 0.9423 - val_loss: 1.4488 - val_accuracy: 0.7331
# Epoch 20/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.1586 - accuracy: 0.9480 - val_loss: 1.4428 - val_accuracy: 0.7289
# Epoch 21/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.1473 - accuracy: 0.9517 - val_loss: 1.5713 - val_accuracy: 0.7361
# Epoch 22/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.1462 - accuracy: 0.9519 - val_loss: 1.6467 - val_accuracy: 0.7319
# Epoch 23/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.1355 - accuracy: 0.9560 - val_loss: 1.6704 - val_accuracy: 0.7426
# Epoch 24/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.1330 - accuracy: 0.9584 - val_loss: 1.6618 - val_accuracy: 0.7354
# Epoch 25/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.1148 - accuracy: 0.9631 - val_loss: 1.5747 - val_accuracy: 0.7400
# Epoch 26/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.1190 - accuracy: 0.9626 - val_loss: 1.8102 - val_accuracy: 0.7374
# Epoch 27/50
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.1102 - accuracy: 0.9659 - val_loss: 1.7199 - val_accuracy: 0.7297
# Epoch 28/50
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.1132 - accuracy: 0.9649 - val_loss: 1.7933 - val_accuracy: 0.7333
# Epoch 29/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.1067 - accuracy: 0.9667 - val_loss: 1.9830 - val_accuracy: 0.7326
# Epoch 30/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.1084 - accuracy: 0.9664 - val_loss: 1.7405 - val_accuracy: 0.7399
# Epoch 31/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0969 - accuracy: 0.9699 - val_loss: 1.8279 - val_accuracy: 0.7356
# Epoch 32/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.1019 - accuracy: 0.9697 - val_loss: 1.8379 - val_accuracy: 0.7313
# Epoch 33/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.1038 - accuracy: 0.9693 - val_loss: 1.7476 - val_accuracy: 0.7319
# Epoch 34/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0923 - accuracy: 0.9726 - val_loss: 1.7625 - val_accuracy: 0.7369
# Epoch 35/50
# 1563/1563 [==============================] - 21s 14ms/step - loss: 0.0905 - accuracy: 0.9732 - val_loss: 1.9835 - val_accuracy: 0.7330
# Epoch 36/50
# 1563/1563 [==============================] - 21s 14ms/step - loss: 0.0935 - accuracy: 0.9738 - val_loss: 1.9132 - val_accuracy: 0.7319
# Epoch 37/50
# 1563/1563 [==============================] - 21s 14ms/step - loss: 0.0977 - accuracy: 0.9716 - val_loss: 1.7175 - val_accuracy: 0.7323
# Epoch 38/50
# 1563/1563 [==============================] - 21s 14ms/step - loss: 0.0790 - accuracy: 0.9771 - val_loss: 2.0455 - val_accuracy: 0.7268
# Epoch 39/50
# 1563/1563 [==============================] - 21s 14ms/step - loss: 0.0887 - accuracy: 0.9735 - val_loss: 1.8158 - val_accuracy: 0.7290
# Epoch 40/50
# 1563/1563 [==============================] - 21s 14ms/step - loss: 0.0750 - accuracy: 0.9781 - val_loss: 2.2559 - val_accuracy: 0.7354
# Epoch 41/50
# 1563/1563 [==============================] - 21s 14ms/step - loss: 0.0922 - accuracy: 0.9739 - val_loss: 2.0106 - val_accuracy: 0.7318
# Epoch 42/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0778 - accuracy: 0.9782 - val_loss: 2.3479 - val_accuracy: 0.7315
# Epoch 43/50
# 1563/1563 [==============================] - 21s 14ms/step - loss: 0.0885 - accuracy: 0.9755 - val_loss: 1.9342 - val_accuracy: 0.7334
# Epoch 44/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0743 - accuracy: 0.9785 - val_loss: 1.9427 - val_accuracy: 0.7337
# Epoch 45/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0832 - accuracy: 0.9769 - val_loss: 2.0703 - val_accuracy: 0.7384
# Epoch 46/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0718 - accuracy: 0.9793 - val_loss: 2.0639 - val_accuracy: 0.7387
# Epoch 47/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0806 - accuracy: 0.9787 - val_loss: 1.7807 - val_accuracy: 0.7320
# Epoch 48/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0778 - accuracy: 0.9790 - val_loss: 2.1490 - val_accuracy: 0.7374
# Epoch 49/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0680 - accuracy: 0.9806 - val_loss: 2.2727 - val_accuracy: 0.7329
# Epoch 50/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0731 - accuracy: 0.9807 - val_loss: 2.2499 - val_accuracy: 0.7373

# %%
# Function to plot learning curves
def plot_learning_curves(history, model_name):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs_range = range(1, len(acc) + 1)
    
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Train Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title(f'{model_name} - Accuracy')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Train Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title(f'{model_name} - Loss')
    plt.legend()
    
    plt.show()

# Plot learning curves for VGG16 model
plot_learning_curves(hist, 'VGG16')

# %%
# Function to plot confusion matrix
def plot_confusion_matrix(cm, class_names, title='Confusion Matrix'):
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.title(title)
    plt.ylabel('Actual Labels')
    plt.xlabel('Predicted Labels')
    plt.show()

# %%
# Function to evaluate model and plot confusion matrix
def evaluate_model(model, x_test, y_test, model_name):
    preds = model.predict(x_test)
    preds_classes = np.argmax(preds, axis=1)
    y_test_classes = y_test.flatten()

    conf_matrix = confusion_matrix(y_test_classes, preds_classes)
    print(f"{model_name} Model Performance:")
    print(classification_report(y_test_classes, preds_classes, target_names=labels))
    
    plot_confusion_matrix(conf_matrix, class_names=labels, title=f'{model_name} Confusion Matrix')

# Evaluate VGG16 model
evaluate_model(model, test_images, test_labels, 'VGG16')
# Out:
# 313/313 [==============================] - 2s 7ms/step
# VGG16 Model Performance:
#               precision    recall  f1-score   support
#
#     airplane       0.77      0.81      0.79      1000
#   automobile       0.84      0.83      0.83      1000
#         bird       0.76      0.60      0.67      1000
#          cat       0.57      0.54      0.55      1000
#         deer       0.63      0.76      0.69      1000
#          dog       0.67      0.64      0.66      1000
#         frog       0.70      0.81      0.75      1000
#        horse       0.81      0.77      0.79      1000
#         ship       0.83      0.85      0.84      1000
#        truck       0.83      0.76      0.79      1000
#
#     accuracy                           0.74     10000
#    macro avg       0.74      0.74      0.74     10000
# weighted avg       0.74      0.74      0.74     10000
